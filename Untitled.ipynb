# %%
import ase

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
a=np.loadtxt('test_jupyeter/charge.dat')[0,:]
b=np.loadtxt('test_jupyeter/charge.dat')[1,:]
c=np.loadtxt('test_jupyeter/charge.dat')[2,:]
d=np.loadtxt('test_jupyeter/charge.dat')[3,:]
x=[1,3,5]
plt.plot(x,a,'o',label='Bader')
plt.plot(x,b,'o',label='Mulliken')
plt.plot(x,c,'o',label='CM5')
plt.plot(x,d,'o',label='Hirshfeld')
plt.xlabel('M')
plt.ylabel('charge')
plt.legend()
plt.savefig('charge.png')
